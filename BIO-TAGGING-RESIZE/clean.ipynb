# %%
# ── cell / file: resize_bboxes.py ────────────────────────────────────────────
from pathlib import Path
import json

# ─────────────────── CONFIG ────────────────────────────────────────────────
SRC_DIR  = Path(r"/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/BIO-TAGGING-RENAME/mcuong_data")     # <── folder with id-fixed files
DST_DIR  = Path(r"/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/BIO-TAGGING-RESIZE/mcuong_data")   # <── will be created if needed
IMG_W, IMG_H = 2481, 3508                          # original image size in pixels

DST_DIR.mkdir(exist_ok=True)

def norm_bbox(b):
    x0, y0, x1, y1 = b
    return [
        int(1000 * x0 / IMG_W),
        int(1000 * y0 / IMG_H),
        int(1000 * x1 / IMG_W),
        int(1000 * y1 / IMG_H),
    ]

for p in SRC_DIR.glob("*.json"):
    data = json.loads(p.read_text(encoding="utf-8"))
    data["bboxes"] = [norm_bbox(b) for b in data["bboxes"]]

    out = DST_DIR / p.name
    out.write_text(json.dumps(data, ensure_ascii=False, indent=2), encoding="utf-8")
    print("✓ bbox-norm:", p.name)

print(f"Done.  Files written to {DST_DIR}")
# Out:
# ✓ bbox-norm: 1C24TDT_00002847.json
# ✓ bbox-norm: 1C24TDT_00002853.json
# ✓ bbox-norm: 1C24TDT_00003708.json
# ✓ bbox-norm: 1C24THS_00001675.json
# ✓ bbox-norm: 1C24THS_00001799.json
# ✓ bbox-norm: 1C24THS_00001857.json
# ✓ bbox-norm: 1C24THS_00001916.json
# ✓ bbox-norm: 1C24THS_00001981.json
# ✓ bbox-norm: 1C24THS_00002013.json
# ✓ bbox-norm: 1C24THS_00002170.json
# ✓ bbox-norm: 1C24THS_00002196.json
# ✓ bbox-norm: 1C24THT_00005608.json
# ✓ bbox-norm: 1C24THT_00005623.json
# ✓ bbox-norm: 1C24TLT_00003719.json
# ✓ bbox-norm: 1C24TLT_00003732.json
# ✓ bbox-norm: 1C24TLT_00004099.json
# ✓ bbox-norm: 1C24TLT_00004105.json
# ✓ bbox-norm: 1C24TLT_00004521.json
# ✓ bbox-norm: 1C24TLT_00004527.json
# ✓ bbox-norm: 1C24TLT_00005255.json
# ✓ bbox-norm: 1C24TLT_00005280.json
# ✓ bbox-norm: 1C24TLT_00005742.json
# ✓ bbox-norm: 1C24TLT_00005755.json
# ✓ bbox-norm: 1C24TLT_00006047.json
# ✓ bbox-norm: 1C24TLT_00006060.json
# ✓ bbox-norm: 1C24TPG_00003832.json
# ✓ bbox-norm: 1C24TPG_00003842.json
# ...
