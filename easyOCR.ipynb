# %%
import easyocr
import json
import os

# === Cấu hình thư mục ===
INPUT_FOLDER = "/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/converted_pngs"
OUTPUT_FOLDER = "/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT"

# Tạo thư mục output nếu chưa có
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Khởi tạo OCR reader
reader = easyocr.Reader(['vi'])

# Lặp qua tất cả ảnh .png
for filename in os.listdir(INPUT_FOLDER):
    if filename.lower().endswith(".png"):
        image_path = os.path.join(INPUT_FOLDER, filename)
        base_name = os.path.splitext(filename)[0]
        output_json = os.path.join(OUTPUT_FOLDER, base_name + ".json")

        print(f"🔍 OCR đang xử lý: {filename}")

        try:
            results = reader.readtext(image_path)

            tokens = []
            for (bbox, text, prob) in results:
                x0 = int(bbox[0][0])
                y0 = int(bbox[0][1])
                x1 = int(bbox[2][0])
                y1 = int(bbox[2][1])
                tokens.append({
                    "text": text,
                    "bbox": [x0, y0, x1, y1]
                })

            with open(output_json, "w", encoding="utf-8") as f:
                json.dump(tokens, f, ensure_ascii=False, indent=2)

            print(f"✅ Đã lưu: {output_json}")
        except Exception as e:
            print(f"❌ Lỗi với {filename}: {e}")
# Out:
# 🔍 OCR đang xử lý: 1C23TTN_00000332.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TTN_00000332.json
# 🔍 OCR đang xử lý: 1C23TYY_00000007.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000007.json
# 🔍 OCR đang xử lý: 1C23TYY_00000010.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000010.json
# 🔍 OCR đang xử lý: 1C23TYY_00000014.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000014.json
# 🔍 OCR đang xử lý: 1C23TYY_00000015.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000015.json
# 🔍 OCR đang xử lý: 1C23TYY_00000020.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000020.json
# 🔍 OCR đang xử lý: 1C23TYY_00000021.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000021.json
# 🔍 OCR đang xử lý: 1C23TYY_00000025.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000025.json
# 🔍 OCR đang xử lý: 1C23TYY_00000037.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000037.json
# 🔍 OCR đang xử lý: 1C23TYY_00000038.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000038.json
# 🔍 OCR đang xử lý: 1C23TYY_00000059.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000059.json
# 🔍 OCR đang xử lý: 1C23TYY_00000075.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000075.json
# 🔍 OCR đang xử lý: 1C23TYY_00000079.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000079.json
# 🔍 OCR đang xử lý: 1C23TYY_00000080.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000080.json
# 🔍 OCR đang xử lý: 1C23TYY_00000085.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TYY_00000085.json
# 🔍 OCR đang xử lý: 1C24TLT_00000533.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00000533.json
# 🔍 OCR đang xử lý: 1C24TLT_00000547.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00000547.json
# 🔍 OCR đang xử lý: 1C24TLT_00000752.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00000752.json
# 🔍 OCR đang xử lý: 1C24TLT_00000775.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00000775.json
# 🔍 OCR đang xử lý: 1C24TLT_00001672.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00001672.json
# 🔍 OCR đang xử lý: 1C24TLT_00001688.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00001688.json
# 🔍 OCR đang xử lý: 1C24TLT_00001888.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00001888.json
# 🔍 OCR đang xử lý: 1C24TLT_00002304.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00002304.json
# 🔍 OCR đang xử lý: 1C24TLT_00002330.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00002330.json
# 🔍 OCR đang xử lý: 1C24TLT_00002842.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00002842.json
# 🔍 OCR đang xử lý: 1C24TLT_00002877.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00002877.json
# 🔍 OCR đang xử lý: 1C24TLT_00003073.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00003073.json
# 🔍 OCR đang xử lý: 1C24TLT_00003098.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00003098.json
# 🔍 OCR đang xử lý: 1C24TLT_00003179.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00003179.json
# 🔍 OCR đang xử lý: 1C24TLT_00003186.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00003186.json
# 🔍 OCR đang xử lý: 1C24TLT_00003719.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00003719.json
# 🔍 OCR đang xử lý: 1C24TLT_00003732.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00003732.json
# 🔍 OCR đang xử lý: 1C24TLT_00004099.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00004099.json
# 🔍 OCR đang xử lý: 1C24TLT_00004105.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00004105.json
# 🔍 OCR đang xử lý: 1C24TLT_00004521.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00004521.json
# 🔍 OCR đang xử lý: 1C24TLT_00004527.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00004527.json
# 🔍 OCR đang xử lý: 1C24TLT_00005255.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00005255.json
# 🔍 OCR đang xử lý: 1C24TLT_00005280.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00005280.json
# 🔍 OCR đang xử lý: 1C24TLT_00005742.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00005742.json
# 🔍 OCR đang xử lý: 1C24TLT_00005755.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00005755.json
# 🔍 OCR đang xử lý: 1C24TLT_00006047.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00006047.json
# 🔍 OCR đang xử lý: 1C24TLT_00006060.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TLT_00006060.json
# 🔍 OCR đang xử lý: 1C24TYY_00000006.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000006.json
# 🔍 OCR đang xử lý: 1C24TYY_00000008.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000008.json
# 🔍 OCR đang xử lý: 1C24TYY_00000027.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000027.json
# 🔍 OCR đang xử lý: 1C24TYY_00000036.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000036.json
# 🔍 OCR đang xử lý: 1C24TYY_00000050.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000050.json
# 🔍 OCR đang xử lý: 1C24TYY_00000051.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000051.json
# 🔍 OCR đang xử lý: 1C24TYY_00000052.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000052.json
# 🔍 OCR đang xử lý: 1C24TYY_00000059.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C24TYY_00000059.json
# 🔍 OCR đang xử lý: 1C25THP_00000029.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25THP_00000029.json
# 🔍 OCR đang xử lý: 1C25TLT_00000274.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TLT_00000274.json
# 🔍 OCR đang xử lý: 1C25TLT_00000292.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TLT_00000292.json
# 🔍 OCR đang xử lý: 1C25TLT_00000507.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TLT_00000507.json
# 🔍 OCR đang xử lý: 1C25TLT_00000518.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TLT_00000518.json
# 🔍 OCR đang xử lý: 1C25TLT_00001052.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TLT_00001052.json
# 🔍 OCR đang xử lý: 1C25TLT_00001064.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TLT_00001064.json
# 🔍 OCR đang xử lý: 1C25TYY_00000011.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TYY_00000011.json
# 🔍 OCR đang xử lý: 1C25TYY_00000013.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TYY_00000013.json
# 🔍 OCR đang xử lý: 1C25TYY_00000014.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TYY_00000014.json
# 🔍 OCR đang xử lý: 1C25TYY_00000015.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C25TYY_00000015.json
# 🔍 OCR đang xử lý: 2C22TVP_00000010.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/2C22TVP_00000010.json
# 🔍 OCR đang xử lý: 2C22TVP_00000059.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/2C22TVP_00000059.json
# 🔍 OCR đang xử lý: 2C24TTT_00001718.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/2C24TTT_00001718.json
# 🔍 OCR đang xử lý: 2C24TTT_00001720.png
# ✅ Đã lưu: /mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/2C24TTT_00001720.json

# %%
from PIL import Image, ImageDraw, ImageFont
import json

# File ảnh và OCR output (bạn đổi qua pytesseract hoặc easyocr tùy ý)
IMAGE_PATH = "/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/mhuy_data/1C23TTN_00000332.png"
OCR_JSON= "/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/easyOCR_OUTPUT/1C23TTN_00000332.json"

# Mở ảnh gốc
img = Image.open(IMAGE_PATH)
draw = ImageDraw.Draw(img)

# Load kết quả OCR
with open(OCR_JSON, "r", encoding="utf-8") as f:
    tokens = json.load(f)

# Vẽ bbox và text lên ảnh
for token in tokens:
    bbox = token["bbox"]
    text = token["text"]
    draw.rectangle(bbox, outline="red", width=2)
    draw.text((bbox[0], bbox[1] - 12), text, fill="blue")

# Hiển thị ảnh (trong Jupyter hoặc lưu ra file)
img.show()  # hoặc img.save("visualized_output.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1414x2000>
