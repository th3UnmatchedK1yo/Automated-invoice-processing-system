# %%
# ── cell / file: json_pretty_to_singleline.py ───────────────────────────────
from pathlib import Path
import json       # <-- separate line
import shutil     # <-- if you actually need shutil later


# ─────────────────── CONFIG ────────────────────────────────────────────────
SRC_DIR = Path(r"/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/BIO-TAGGING-RESIZE/mcuong_data")          # retagged, pretty-printed JSONs
DST_DIR = Path(r"/mnt/c/Users/Legion/Documents/jimmy tran/Automated-invoice-processing-system/BIO-TAGGING-SingleLINE/mcuong_data")         # will be created
DST_DIR.mkdir(exist_ok=True)

for p in SRC_DIR.glob("*.json"):
    data = json.loads(p.read_text(encoding="utf-8"))

    # dump with no spaces → separators=(",", ":")
    single_line = json.dumps(data, ensure_ascii=False, separators=(",", ":"))

    (DST_DIR / p.name).write_text(single_line + "\n", encoding="utf-8")
    print("✓ single-line:", p.name)

print(f"Done.  Files written to {DST_DIR}")
# Out:
# ✓ single-line: 1C24TDT_00002847.json
# ✓ single-line: 1C24TDT_00002853.json
# ✓ single-line: 1C24TDT_00003708.json
# ✓ single-line: 1C24THS_00001675.json
# ✓ single-line: 1C24THS_00001799.json
# ✓ single-line: 1C24THS_00001857.json
# ✓ single-line: 1C24THS_00001916.json
# ✓ single-line: 1C24THS_00001981.json
# ✓ single-line: 1C24THS_00002013.json
# ✓ single-line: 1C24THS_00002170.json
# ✓ single-line: 1C24THS_00002196.json
# ✓ single-line: 1C24THT_00005608.json
# ✓ single-line: 1C24THT_00005623.json
# ✓ single-line: 1C24TLT_00003719.json
# ✓ single-line: 1C24TLT_00003732.json
# ✓ single-line: 1C24TLT_00004099.json
# ✓ single-line: 1C24TLT_00004105.json
# ✓ single-line: 1C24TLT_00004521.json
# ✓ single-line: 1C24TLT_00004527.json
# ✓ single-line: 1C24TLT_00005255.json
# ✓ single-line: 1C24TLT_00005280.json
# ✓ single-line: 1C24TLT_00005742.json
# ✓ single-line: 1C24TLT_00005755.json
# ✓ single-line: 1C24TLT_00006047.json
# ✓ single-line: 1C24TLT_00006060.json
# ...
